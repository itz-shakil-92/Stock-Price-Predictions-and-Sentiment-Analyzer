# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ta.trend import MACD
from ta.momentum import RSIIndicator
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle, os

# %%
df = pd.read_csv('../data/itc.csv')  
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].apply(pd.to_numeric, errors='coerce')

# %%
df['RSI'] = RSIIndicator(close=df['Close']).rsi()
macd = MACD(close=df['Close'])
df['MACD'] = macd.macd()
df['MACD_Signal'] = macd.macd_signal()
df['SMA7'] = df['Close'].rolling(window=7).mean()
df['SMA21'] = df['Close'].rolling(window=21).mean()
df.dropna(inplace=True)

# %%
features = ['Open', 'High', 'Low', 'Volume', 'RSI', 'MACD', 'MACD_Signal', 'SMA7', 'SMA21']
X = df[features]
y = df['Close']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 X = df[features]
#       3 y = df['Close']
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File c:\Python311\Lib\site-packages\sklearn\model_selection\_split.py:2649, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2646 arrays = indexable(*arrays)
#    2648 n_samples = _num_samples(arrays[0])
# -> 2649 n_train, n_test = _validate_shuffle_split(
#    2650     n_samples, test_size, train_size, default_test_size=0.25
#    2651 )
#    2653 if shuffle is False:
#    2654     if stratify is not None:
#
# File c:\Python311\Lib\site-packages\sklearn\model_selection\_split.py:2305, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2302 n_train, n_test = int(n_train), int(n_test)
#    2304 if n_train == 0:
# -> 2305     raise ValueError(
#    2306         "With n_samples={}, test_size={} and train_size={}, the "
#    2307         "resulting train set will be empty. Adjust any of the "
#    2308         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2309     )
#    2311 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
model = RandomForestRegressor(n_estimators=300, max_depth=12, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=300, random_state=42)

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# MAE: 2.01
# RMSE: 2.66
# R² Score: 0.98

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'].iloc[-len(y_test):], y_test, label='Actual')
plt.plot(df['Date'].iloc[-len(y_test):], y_pred, label='Predicted')
plt.title("Stock Price Prediction")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid()
plt.legend()
plt.show()

# %%
model_name = 'itc'  
os.makedirs('../models', exist_ok=True)
with open(f'../models/{model_name}.pkl', 'wb') as f:
    pickle.dump(model, f)

print(f"✅ Model saved as ../models/{model_name}.pkl")
# Out:
# ✅ Model saved as ../models/wipro.pkl
